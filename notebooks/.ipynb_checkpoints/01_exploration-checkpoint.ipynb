# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\ahyo\IDXExchange\IDXExchange

# %% [markdown]
# ## Week 1: Orientation and Setup
#
# Note on keys: The following fields are considered `InKeyIndex` fields and may be queried in batches up to 300,000 at a time: `ListingId` , `ListingKey` , `ModificationTimestamp` , `PhotosChangeTimestamp` , `PhotosCount` , `PostalCode` , `StandardStatus`.
#
# | Key name | Key type | Description |
# |---|---|---|
# |`ListingId`| String | Well-known identifier for listing. Intended for human use for retrieving listings. |
# |`ListingKey`| String | Unique identifier of listing from immediate source. |
# | `ModificationTimestamp` | DateTimeOffset | System generated timestamp of last modification |
# | `PhotosChangeTimestamp` | DateTimeOffset | System generated timestamp of update/change to photos |
# | `PhotosCount` | Int32 | Total number of pictures included with listing |
# | `PostalCode` | String | Postal code |
# | `StandardStatus` | StandardStatus Enum | Current status of listing |

# %%
keys = ['ListingId', 'ListingKey', 'ModificationTimestamp', 'PhotosChangeTimestamp', 'PhotosCount', 'PostalCode', 'StandardStatus']

# %%
dp = Path('../data/')
csv_names = []
for item in dp.iterdir():
    if item.is_file():
        print(item.name)
        csv_names.append(item.name)
# Out:
# CRMLSSold20220101_20231231_filled.csv
# CRMLSSold202401_filled.csv
# CRMLSSold202402_filled.csv
# CRMLSSold202403_filled.csv
# CRMLSSold202404_filled.csv
# CRMLSSold202405_filled.csv
# CRMLSSold202406_filled.csv
# CRMLSSold202407_filled.csv
# CRMLSSold202408.csv
# CRMLSSold202409.csv
# CRMLSSold202410.csv
# CRMLSSold202411.csv
# CRMLSSold202412.csv
# CRMLSSold202501_filled.csv
# CRMLSSold202502.csv
# CRMLSSold202503.csv
# CRMLSSold202504.csv
# CRMLSSold202505.csv
# CRMLSSold202506.csv
# CRMLSSold202507.csv
# CRMLSSold202508.csv
# CRMLSSold202509.csv
# CRMLSSold202510.csv
# CRMLSSold202511.csv
# CRMLSSold202512.csv
# CRMLSSold202601.csv
# CRMLSSold202602.csv
# CRMLSSold202603.csv
# CRMLSSold202604.csv
# CRMLSSold202605.csv

# %%
len(csv_names)
# Out:
# 30

# %%
df = pd.DataFrame()
for name in csv_names:
    path = Path("../data/" + name)
    df2 = pd.read_csv(path)
    #print(len(df2))
    df = pd.concat([df, df2], join='outer', ignore_index=True)
    #print(len(df))
df = df[df['PropertyType'] == 'Residential']
df = df[df['PropertySubType'] == 'SingleFamilyResidence']
df.head()
# Out:
# C:\Users\ahyo\AppData\Local\Temp\ipykernel_24484\2793060070.py:4: DtypeWarning: Columns (78,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv(path)
# C:\Users\ahyo\AppData\Local\Temp\ipykernel_24484\2793060070.py:4: DtypeWarning: Columns (2,36,39,56,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv(path)
# C:\Users\ahyo\AppData\Local\Temp\ipykernel_24484\2793060070.py:4: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv(path)
# C:\Users\ahyo\AppData\Local\Temp\ipykernel_24484\2793060070.py:4: DtypeWarning: Columns (4,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv(path)
#        Flooring ViewYN WaterfrontYN BasementYN PoolPrivateYN  \
# 3           NaN   True          NaN        NaN         False
# 6           NaN   True          NaN        NaN         False
# 7           NaN  False          NaN        NaN         False
# 12  Carpet,Tile   True          NaN        NaN          True
# 14          NaN   True          NaN        NaN         False
#
#     OriginalListPrice  ListingKey               ListAgentEmail   CloseDate  \
# 3           2499999.0   556365765        bryanmeathe@gmail.com  2022-01-04
# 6            565000.0   556365286  joseph@labelrealtygroup.com  2022-01-10
# 7            349999.0   556365284          eaguayo08@gmail.com  2022-03-23
# 12           599000.0   556364261            gcrb714@gmail.com  2022-01-10
# 14           399990.0   556363890       allegra@3treehomes.com  2022-01-19
#
#     ClosePrice  ... GarageSpaces HighSchoolDistrict  PostalCode  \
# 3    2499999.0  ...          2.0   Carlsbad Unified       92008
# 6     640000.0  ...          1.0   Rim of the World       92352
# 7     438000.0  ...          2.0    Fontana Unified       92336
# 12    615000.0  ...          2.0                NaN       92234
# 14    399990.0  ...          2.0   Paradise Unified       95969
#
#     AssociationFee LotSizeSquareFeet MiddleOrJuniorSchoolDistrict  latfilled  \
# 3            140.0           13376.0                          NaN      False
# 6              0.0            3397.0                          NaN      False
# 7              0.0            9900.0                          NaN      False
# 12           195.0            6098.0                          NaN      False
# 14             0.0           12197.0                          NaN      False
#
#     lonfilled  BuyerAgentAOR ListAgentAOR
# 3       False            NaN          NaN
# 6       False            NaN          NaN
# 7       False            NaN          NaN
# 12      False            NaN          NaN
# 14      False            NaN          NaN
#
# [5 rows x 82 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 399157 entries, 3 to 794267
# Data columns (total 82 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Flooring                      256352 non-null  object
#  1   ViewYN                        359640 non-null  object
#  2   WaterfrontYN                  175 non-null     object
#  3   BasementYN                    9747 non-null    object
#  4   PoolPrivateYN                 358610 non-null  object
#  5   OriginalListPrice             398378 non-null  float64
#  6   ListingKey                    399157 non-null  int64
#  7   ListAgentEmail                398296 non-null  object
#  8   CloseDate                     399157 non-null  object
#  9   ClosePrice                    399155 non-null  float64
#  10  ListAgentFirstName            395752 non-null  object
#  11  ListAgentLastName             399120 non-null  object
#  12  Latitude                      398964 non-null  float64
#  13  Longitude                     398964 non-null  float64
#  14  UnparsedAddress               398464 non-null  object
#  15  PropertyType                  399157 non-null  object
#  16  LivingArea                    398947 non-null  float64
#  17  ListPrice                     399157 non-null  float64
#  18  DaysOnMarket                  399157 non-null  float64
#  19  ListOfficeName                399157 non-null  object
#  20  BuyerOfficeName               392605 non-null  object
#  21  CoListOfficeName              92611 non-null   object
#  22  ListAgentFullName             399071 non-null  object
#  23  CoListAgentFirstName          90108 non-null   object
#  24  CoListAgentLastName           90358 non-null   object
#  25  BuyerAgentMlsId               398699 non-null  object
#  26  BuyerAgentFirstName           396868 non-null  object
#  27  BuyerAgentLastName            398992 non-null  object
#  28  FireplacesTotal               0 non-null       float64
#  29  AssociationFeeFrequency       98998 non-null   object
#  30  AboveGradeFinishedArea        0 non-null       float64
#  31  ListingKeyNumeric             399157 non-null  float64
#  32  MLSAreaMajor                  342155 non-null  object
#  33  TaxAnnualAmount               0 non-null       float64
#  34  CountyOrParish                399157 non-null  object
#  35  MlsStatus                     399157 non-null  object
#  36  ElementarySchool              55431 non-null   object
#  37  AttachedGarageYN              353048 non-null  object
#  38  ParkingTotal                  391614 non-null  float64
#  39  BuilderName                   18758 non-null   object
#  40  PropertySubType               399157 non-null  object
#  41  LotSizeAcres                  392270 non-null  float64
#  42  SubdivisionName               137615 non-null  object
#  43  BuyerOfficeAOR                377232 non-null  object
#  44  YearBuilt                     398849 non-null  float64
#  45  BuyerAgencyCompensationType   120906 non-null  object
#  46  StreetNumberNumeric           398364 non-null  float64
#  47  ListingId                     399157 non-null  object
#  48  BathroomsTotalInteger         399082 non-null  float64
#  49  City                          398619 non-null  object
#  50  BuyerAgencyCompensation       120877 non-null  float64
#  51  TaxYear                       0 non-null       float64
#  52  BuildingAreaTotal             24660 non-null   float64
#  53  BedroomsTotal                 399157 non-null  float64
#  54  ContractStatusChangeDate      390914 non-null  object
#  55  ElementarySchoolDistrict      0 non-null       float64
#  56  CoBuyerAgentFirstName         35640 non-null   object
#  57  PurchaseContractDate          399014 non-null  object
#  58  ListingContractDate           399157 non-null  object
#  59  BelowGradeFinishedArea        2328 non-null    float64
#  60  BusinessType                  0 non-null       object
#  61  StateOrProvince               399156 non-null  object
#  62  CoveredSpaces                 0 non-null       float64
#  63  MiddleOrJuniorSchool          56016 non-null   object
#  64  FireplaceYN                   397207 non-null  object
#  65  Stories                       344560 non-null  float64
#  66  HighSchool                    71976 non-null   object
#  67  Levels                        357468 non-null  object
#  68  LotSizeDimensions             24508 non-null   object
#  69  LotSizeArea                   392367 non-null  float64
#  70  MainLevelBedrooms             236733 non-null  float64
#  71  NewConstructionYN             359618 non-null  object
#  72  GarageSpaces                  384560 non-null  float64
#  73  HighSchoolDistrict            295857 non-null  object
#  74  PostalCode                    399155 non-null  object
#  75  AssociationFee                276911 non-null  float64
#  76  LotSizeSquareFeet             392331 non-null  float64
#  77  MiddleOrJuniorSchoolDistrict  0 non-null       float64
#  78  latfilled                     168814 non-null  object
#  79  lonfilled                     168814 non-null  object
#  80  BuyerAgentAOR                 274554 non-null  object
#  81  ListAgentAOR                  278200 non-null  object
# dtypes: float64(30), int64(1), object(51)
# memory usage: 252.8+ MB

# %%
price_cols = ['OriginalListPrice', 'ClosePrice', 'ListPrice']
df.sort_values('ClosePrice', ascending=False)[price_cols].head(10)
# Out:
#         OriginalListPrice   ClosePrice   ListPrice
# 633388           979000.0  989500000.0    979000.0
# 508727           998900.0  970000000.0    974777.0
# 558249         15500000.0  900000000.0  15500000.0
# 605180           875000.0  875000000.0    875000.0
# 611857           835800.0  835800000.0    835800.0
# 622462           839900.0  815000000.0    809000.0
# 767360           849900.0  796000000.0    824900.0
# 766469           750000.0  768500000.0    750000.0
# 606564           699000.0  751412000.0    699000.0
# 665009           750000.0  740000000.0    735000.0

# %%
df[price_cols].describe()
# Out:
#        OriginalListPrice    ClosePrice     ListPrice
# count       3.983780e+05  3.991550e+05  3.991570e+05
# mean        1.336880e+06  1.285092e+06  1.248959e+06
# std         6.990745e+06  5.237207e+06  1.559621e+06
# min         0.000000e+00  0.000000e+00  4.500000e+02
# 25%         6.250000e+05  6.200000e+05  6.190000e+05
# 50%         8.950000e+05  8.890000e+05  8.800000e+05
# 75%         1.400000e+06  1.425000e+06  1.399000e+06
# max         1.390000e+09  9.895000e+08  2.450000e+08

# %% [markdown]
# ## Week 2: Data Exploration

# %%
for c in price_cols:
    plt.figure()
    sns.histplot(df[df[c] < df[c].quantile(0.99)][c])
    plt.title(c)
    plt.show()

# %%
other_cols = ['LivingArea', 'BedroomsTotal', 'BathroomsTotalInteger', 'LotSizeSquareFeet']
fig, axes = plt.subplots(2, 2, figsize=(8,6))
for i,c in enumerate(other_cols):
    sns.histplot(df[df[c] < df[c].quantile(0.99)][c], ax=axes[i//2, i%2])
    axes[i//2, i%2].set_title(c)
plt.tight_layout()
plt.show()

# %%
df[other_cols].describe()
# Out:
#          LivingArea  BedroomsTotal  BathroomsTotalInteger  LotSizeSquareFeet
# count  3.989470e+05  399157.000000          399082.000000       3.923310e+05
# mean   2.036718e+03       3.476710               2.610133       2.454994e+05
# std    3.803275e+03       0.960517               1.182700       1.387443e+07
# min    0.000000e+00       0.000000               0.000000       0.000000e+00
# 25%    1.373000e+03       3.000000               2.000000       5.663000e+03
# 50%    1.800000e+03       3.000000               2.000000       7.247000e+03
# 75%    2.417500e+03       4.000000               3.000000       1.034000e+04
# max    2.308680e+06      45.000000             175.000000       2.087221e+09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 399157 entries, 3 to 794267
# Data columns (total 82 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Flooring                      256352 non-null  object
#  1   ViewYN                        359640 non-null  object
#  2   WaterfrontYN                  175 non-null     object
#  3   BasementYN                    9747 non-null    object
#  4   PoolPrivateYN                 358610 non-null  object
#  5   OriginalListPrice             398378 non-null  float64
#  6   ListingKey                    399157 non-null  int64
#  7   ListAgentEmail                398296 non-null  object
#  8   CloseDate                     399157 non-null  object
#  9   ClosePrice                    399155 non-null  float64
#  10  ListAgentFirstName            395752 non-null  object
#  11  ListAgentLastName             399120 non-null  object
#  12  Latitude                      398964 non-null  float64
#  13  Longitude                     398964 non-null  float64
#  14  UnparsedAddress               398464 non-null  object
#  15  PropertyType                  399157 non-null  object
#  16  LivingArea                    398947 non-null  float64
#  17  ListPrice                     399157 non-null  float64
#  18  DaysOnMarket                  399157 non-null  float64
#  19  ListOfficeName                399157 non-null  object
#  20  BuyerOfficeName               392605 non-null  object
#  21  CoListOfficeName              92611 non-null   object
#  22  ListAgentFullName             399071 non-null  object
#  23  CoListAgentFirstName          90108 non-null   object
#  24  CoListAgentLastName           90358 non-null   object
#  25  BuyerAgentMlsId               398699 non-null  object
#  26  BuyerAgentFirstName           396868 non-null  object
#  27  BuyerAgentLastName            398992 non-null  object
#  28  FireplacesTotal               0 non-null       float64
#  29  AssociationFeeFrequency       98998 non-null   object
#  30  AboveGradeFinishedArea        0 non-null       float64
#  31  ListingKeyNumeric             399157 non-null  float64
#  32  MLSAreaMajor                  342155 non-null  object
#  33  TaxAnnualAmount               0 non-null       float64
#  34  CountyOrParish                399157 non-null  object
#  35  MlsStatus                     399157 non-null  object
#  36  ElementarySchool              55431 non-null   object
#  37  AttachedGarageYN              353048 non-null  object
#  38  ParkingTotal                  391614 non-null  float64
#  39  BuilderName                   18758 non-null   object
#  40  PropertySubType               399157 non-null  object
#  41  LotSizeAcres                  392270 non-null  float64
#  42  SubdivisionName               137615 non-null  object
#  43  BuyerOfficeAOR                377232 non-null  object
#  44  YearBuilt                     398849 non-null  float64
#  45  BuyerAgencyCompensationType   120906 non-null  object
#  46  StreetNumberNumeric           398364 non-null  float64
#  47  ListingId                     399157 non-null  object
#  48  BathroomsTotalInteger         399082 non-null  float64
#  49  City                          398619 non-null  object
#  50  BuyerAgencyCompensation       120877 non-null  float64
#  51  TaxYear                       0 non-null       float64
#  52  BuildingAreaTotal             24660 non-null   float64
#  53  BedroomsTotal                 399157 non-null  float64
#  54  ContractStatusChangeDate      390914 non-null  object
#  55  ElementarySchoolDistrict      0 non-null       float64
#  56  CoBuyerAgentFirstName         35640 non-null   object
#  57  PurchaseContractDate          399014 non-null  object
#  58  ListingContractDate           399157 non-null  object
#  59  BelowGradeFinishedArea        2328 non-null    float64
#  60  BusinessType                  0 non-null       object
#  61  StateOrProvince               399156 non-null  object
#  62  CoveredSpaces                 0 non-null       float64
#  63  MiddleOrJuniorSchool          56016 non-null   object
#  64  FireplaceYN                   397207 non-null  object
#  65  Stories                       344560 non-null  float64
#  66  HighSchool                    71976 non-null   object
#  67  Levels                        357468 non-null  object
#  68  LotSizeDimensions             24508 non-null   object
#  69  LotSizeArea                   392367 non-null  float64
#  70  MainLevelBedrooms             236733 non-null  float64
#  71  NewConstructionYN             359618 non-null  object
#  72  GarageSpaces                  384560 non-null  float64
#  73  HighSchoolDistrict            295857 non-null  object
#  74  PostalCode                    399155 non-null  object
#  75  AssociationFee                276911 non-null  float64
#  76  LotSizeSquareFeet             392331 non-null  float64
#  77  MiddleOrJuniorSchoolDistrict  0 non-null       float64
#  78  latfilled                     168814 non-null  object
#  79  lonfilled                     168814 non-null  object
#  80  BuyerAgentAOR                 274554 non-null  object
#  81  ListAgentAOR                  278200 non-null  object
# dtypes: float64(30), int64(1), object(51)
# memory usage: 252.8+ MB

# %% [markdown]
# ## Week 3: Data Preprocessing

# %%
import re
import datetime
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.compose import ColumnTransformer

# %%
# keep columns with at least 50% non-null values
df_cleaned = df.dropna(thresh=len(df) * 0.50, axis=1)
df_cleaned = df_cleaned.dropna(subset=['ClosePrice'])
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 82018 entries, 5 to 162846
# Data columns (total 57 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Flooring                     52550 non-null  object
#  1   ViewYN                       74893 non-null  object
#  2   PoolPrivateYN                72480 non-null  object
#  3   OriginalListPrice            81859 non-null  float64
#  4   ListingKey                   82018 non-null  int64
#  5   ListAgentEmail               81937 non-null  object
#  6   CloseDate                    82018 non-null  object
#  7   ClosePrice                   82018 non-null  float64
#  8   ListAgentFirstName           81225 non-null  object
#  9   ListAgentLastName            82015 non-null  object
#  10  Latitude                     81946 non-null  float64
#  11  Longitude                    81946 non-null  float64
#  12  UnparsedAddress              81942 non-null  object
#  13  PropertyType                 82018 non-null  object
#  14  LivingArea                   81971 non-null  float64
#  15  ListPrice                    82018 non-null  float64
#  16  DaysOnMarket                 82018 non-null  int64
#  17  ListOfficeName               82018 non-null  object
#  18  BuyerOfficeName              80436 non-null  object
#  19  ListAgentFullName            82015 non-null  object
#  20  BuyerAgentMlsId              81944 non-null  object
#  21  BuyerAgentFirstName          81545 non-null  object
#  22  BuyerAgentLastName           81990 non-null  object
#  23  ListingKeyNumeric            82018 non-null  int64
#  24  MLSAreaMajor                 70639 non-null  object
#  25  CountyOrParish               82018 non-null  object
#  26  MlsStatus                    82018 non-null  object
#  27  AttachedGarageYN             72898 non-null  object
#  28  ParkingTotal                 81672 non-null  float64
#  29  PropertySubType              82018 non-null  object
#  30  LotSizeAcres                 80623 non-null  float64
#  31  BuyerOfficeAOR               78654 non-null  object
#  32  YearBuilt                    81961 non-null  float64
#  33  BuyerAgencyCompensationType  42261 non-null  object
#  34  StreetNumberNumeric          81926 non-null  float64
#  35  ListingId                    82018 non-null  object
#  36  BathroomsTotalInteger        81996 non-null  float64
#  37  City                         81919 non-null  object
#  38  BuyerAgencyCompensation      42247 non-null  float64
#  39  BedroomsTotal                82018 non-null  float64
#  40  ContractStatusChangeDate     81562 non-null  object
#  41  PurchaseContractDate         82012 non-null  object
#  42  ListingContractDate          82018 non-null  object
#  43  StateOrProvince              82018 non-null  object
#  44  FireplaceYN                  81969 non-null  object
#  45  Stories                      69707 non-null  float64
#  46  Levels                       72285 non-null  object
#  47  LotSizeArea                  80639 non-null  float64
#  48  MainLevelBedrooms            47794 non-null  float64
#  49  NewConstructionYN            76224 non-null  object
#  50  GarageSpaces                 79229 non-null  float64
#  51  HighSchoolDistrict           61457 non-null  object
#  52  PostalCode                   82018 non-null  object
#  53  AssociationFee               56334 non-null  float64
#  54  LotSizeSquareFeet            80635 non-null  float64
#  55  latfilled                    82018 non-null  bool
#  56  lonfilled                    82018 non-null  bool
# dtypes: bool(2), float64(19), int64(3), object(33)
# memory usage: 35.2+ MB

# %%
df_cleaned.iloc[0]
# Out:
# Flooring                                                                     NaN
# ViewYN                                                                     False
# PoolPrivateYN                                                              False
# OriginalListPrice                                                       759900.0
# ListingKey                                                             522107581
# ListAgentEmail                                              mdarwich12@gmail.com
# CloseDate                                                             2024-01-05
# ClosePrice                                                              815000.0
# ListAgentFirstName                                                       Michael
# ListAgentLastName                                                        Darwich
# Latitude                                                               32.659315
# Longitude                                                            -117.096922
# UnparsedAddress                                                    2811 C Avenue
# PropertyType                                                         Residential
# LivingArea                                                                1974.0
# ListPrice                                                               759900.0
# DaysOnMarket                                                                  33
# ListOfficeName                 Berkshire Hathaway HomeServices California Pro...
# BuyerOfficeName                                      FOSTER HAMILTON Real Estate
# ListAgentFullName                                                Michael Darwich
# BuyerAgentMlsId                                                      SAND-606727
# BuyerAgentFirstName                                                      Charles
# BuyerAgentLastName                                                        Street
# ListingKeyNumeric                                                      522107581
# MLSAreaMajor                                               91950 - National City
# CountyOrParish                                                         San Diego
# MlsStatus                                                                 Closed
# AttachedGarageYN                                                            True
# ParkingTotal                                                                 2.0
# PropertySubType                                            SingleFamilyResidence
# LotSizeAcres                                                                 NaN
# BuyerOfficeAOR                                                          SanDiego
# YearBuilt                                                                 2023.0
# BuyerAgencyCompensationType                                                Item1
# StreetNumberNumeric                                                       2811.0
# ListingId                                                              210014555
# BathroomsTotalInteger                                                        4.0
# City                                                               National City
# BuyerAgencyCompensation                                                      2.0
# BedroomsTotal                                                                4.0
# ContractStatusChangeDate                                              2024-01-05
# PurchaseContractDate                                                  2021-06-30
# ListingContractDate                                                   2021-03-08
# StateOrProvince                                                               CA
# FireplaceYN                                                                False
# Stories                                                                      2.0
# Levels                                                                       Two
# LotSizeArea                                                                  NaN
# MainLevelBedrooms                                                            NaN
# NewConstructionYN                                                          False
# GarageSpaces                                                                 2.0
# HighSchoolDistrict                                                           NaN
# PostalCode                                                                 91950
# AssociationFee                                                               NaN
# LotSizeSquareFeet                                                            NaN
# latfilled                                                                   True
# lonfilled                                                                   True
# Name: 5, dtype: object

# %%
df_cleaned[date_cols].isna().sum()
# Out:
# CloseDate                     0
# ContractStatusChangeDate    456
# PurchaseContractDate          6
# ListingContractDate           0
# dtype: int64

# %%
date_cols = df_cleaned.filter(regex='(?i)Date').columns.tolist()
df_cleaned[date_cols] = pd.to_datetime(df_cleaned[date_cols].stack(), format='%Y-%m-%d').unstack()

# %%
cat_cols = df_cleaned.columns[df_cleaned.nunique() < 15].tolist()
bool_cols = df_cleaned.columns[df_cleaned.nunique() == 2].tolist()
cat_cols_no_bool = [c for c in cat_cols if c not in bool_cols]

# %%
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
encoded_data = encoder.fit_transform(df_cleaned[cat_cols])
encoded_df = pd.DataFrame(encoded_data, columns=encoder.get_feature_names_out(cat_cols))

# %%
# Onehot encoding pipeline
ct = ColumnTransformer(
    transformers=[
        ('binary', OrdinalEncoder(), bool_cols),
        ('encoder', OneHotEncoder(sparse_output=False, handle_unknown='ignore'), cat_cols_no_bool)
    ],
    remainder='passthrough'
)

transformed_array = ct.fit_transform(df_cleaned)

encoded_df = pd.DataFrame(transformed_array, columns=ct.get_feature_names_out())
encoded_df.columns = encoded_df.columns.str.replace(r'^(encoder__|remainder__|binary__)', '', regex=True)

# %%
encoded_df.dtypes
# Out:
# ViewYN                object
# PoolPrivateYN         object
# AttachedGarageYN      object
# FireplaceYN           object
# Stories               object
#                        ...
# GarageSpaces          object
# HighSchoolDistrict    object
# PostalCode            object
# AssociationFee        object
# LotSizeSquareFeet     object
# Length: 80, dtype: object
